# %%
import pandas as pd 
import os
desktop_path = os.path.expanduser("~/Desktop")

playlist_file = os.path.join(desktop_path, "spotify_dataset.csv")
song_attr_file = os.path.join(desktop_path, "Spotify_Song_Attributes.csv")

playlist_df = pd.read_csv(playlist_file, on_bad_lines='skip')
song_attr_df = pd.read_csv(song_attr_file)

playlist_df.describe()
# Out:
#                                  user_id  "artistname"  "trackname"  \
# count                           12891680      12858108     12891592
# unique                             15918        289820      2032043
# top     4398de6902abde3351347b048fcdc287     Daft Punk        Intro
# freq                              295275         36086         6676
#
#         "playlistname"
# count         12890434
# unique          157504
# top            Starred
# freq           1337085

# %%
#fixing column names (removing spaces, quotes, uppercases)
playlist_df.columns = (
    playlist_df.columns
    .str.replace('"', '') 
    .str.strip()         
    .str.lower()   
)
print(playlist_df.columns.tolist())
# Out:
# ['user_id', 'artistname', 'trackname', 'playlistname']

# %%
#cleaning the dataset (removing nulls and duplicates)
new_playlist_df = playlist_df.dropna(subset=['artistname', 'trackname']).copy()

new_playlist_df['artistname'] = new_playlist_df['artistname'].str.strip()
new_playlist_df['trackname'] = new_playlist_df['trackname'].str.strip()

new_playlist_df = new_playlist_df.drop_duplicates(subset=['artistname', 'trackname'])
new_playlist_df = new_playlist_df.reset_index(drop=True)

print(new_playlist_df.describe())
# Out:
#                                  user_id       artistname trackname  \
# count                            2790680          2790680   2790680
# unique                             14062           289778   2005143
# top     4398de6902abde3351347b048fcdc287  Various Artists     Intro
# freq                              138074             6780      1589
#
#        playlistname
# count       2789536
# unique        92871
# top         Starred
# freq         194353

# %%
new_playlist_df.shape
# Out:
# (2790680, 4)

# %%
desktop_path = os.path.expanduser("~/Desktop")

filename = "cleaned_spotify_playlists.csv"

new_playlist_df.to_csv(os.path.join(desktop_path, filename), index=False)

# %%
#cleaning dataset 2
song_attr_df.dropna(subset=['artistName', 'genre', 'msPlayed', 'danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo','type','id','uri','track_href','analysis_url','duration_ms','time_signature'], inplace=True)  # Drop rows with missing critical values

song_attr_df.drop_duplicates(inplace=True)

for col in song_attr_df.select_dtypes(include=['object']).columns:
    song_attr_df[col] = song_attr_df[col].astype(str).str.lower().str.strip()

song_attr_df.columns = [col.strip().lower().replace(" ", "_") for col in song_attr_df.columns]
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
numeric_cols = song_attr_df.select_dtypes(include=['number']).columns
song_attr_df[numeric_cols] = scaler.fit_transform(song_attr_df[numeric_cols])
song_attr_df = song_attr_df.apply(lambda x: x.str.encode('utf-8').str.decode('utf-8') if x.dtype == "object" else x)

print(song_attr_df)

song_attr_df.to_csv("cleaned_dataset.csv", index=False)

print("Dataset cleaned and saved as 'cleaned_dataset.csv'")

print(song_attr_df.head())
# Out:
#                                               trackname  \
# 1     "in the hall of the mountain king" from peer g...
# 2                                    #brooklynbloodpop!
# 3                                                   $10
# 4                            (i just) died in your arms
# 5                                         (l)only child
# ...                                                 ...
# 5034                                            younger
# 5035                                 younger with time.
# 5037                your love is my drug (8 bit slowed)
# 5038                                         your power
# 5039                            your voice / bethel, ny
#
#                      artistname  msplayed              genre  danceability  \
# 1     london symphony orchestra  0.011405  british orchestra      0.486680
# 2                          syko  0.000919         glitchcore      0.707992
# 3                  good morning  0.000158   experimental pop      0.639344
# 4                  cutting crew  0.034761         album rock      0.640369
# 5                   salem ilese  0.014132              alt z      0.660861
# ...                         ...       ...                ...           ...
# 5034                       ruel  0.033292              alt z      0.763320
# 5035                  ben zaidi  0.004221           folk-pop      0.550205
# 5037                just valery  0.000616          sad lo-fi      0.288934
# 5038              billie eilish  0.006240            art pop      0.647541
# 5039                      jaden  0.001349            pop rap      0.573770
#
#         energy       key  loudness  mode  speechiness  ...  liveness  \
# 1     0.129189  0.636364  0.539908   1.0     0.054198  ...  0.081035
# 2     0.814614  0.090909  0.849114   0.0     0.124336  ...  0.363220
# 3     0.596160  0.363636  0.715586   1.0     0.033369  ...  0.100202
# 4     0.726431  1.000000  0.680117   0.0     0.047184  ...  0.040038
# 5     0.611191  0.727273  0.801682   0.0     0.145590  ...  0.225855
# ...        ...       ...       ...   ...          ...  ...       ...
# 5034  0.476912  1.000000  0.762152   0.0     0.093518  ...  0.101267
# 5035  0.142216  0.181818  0.556044   1.0     0.035175  ...  0.090619
# 5037  0.157247  0.545455  0.760443   1.0     0.033050  ...  0.478224
# 5038  0.283510  0.818182  0.621898   0.0     0.085122  ...  0.221595
# 5039  0.343635  0.272727  0.660563   1.0     0.032519  ...  0.091684
#
#        valence     tempo            type                      id  \
# 1     0.123732  0.475203  audio_features  14qcrx6dfjvcj0h8ov8ouw
# 2     0.516227  0.558909  audio_features  7k9z3yfnnlv5kwtjqygjnu
# 3     0.908722  0.512155  audio_features  3koawrm1ro0tgmeqj3qt9j
# 4     0.514199  0.528989  audio_features  4byefobulxpcqvo1kw8wdm
# 5     0.654158  0.666713  audio_features  22ljag2yxlsjiwduiddcfk
# ...        ...       ...             ...                     ...
# 5034  0.460446  0.576026  audio_features  2qxicqg06ot0ijkbznpgqv
# 5035  0.248479  0.555124  audio_features  6o8pm5relgjd5i8gdy3irt
# 5037  0.251521  0.275839  audio_features  1eothndm6kqfb2idifr30n
# 5038  0.210953  0.548875  audio_features  042sl6mn83jhyleqdk7ui0
# 5039  0.434077  0.488548  audio_features  3bcn2pcy0ktg1zm8tz9msb
#
#                                        uri  \
# 1     spotify:track:14qcrx6dfjvcj0h8ov8ouw
# 2     spotify:track:7k9z3yfnnlv5kwtjqygjnu
# 3     spotify:track:3koawrm1ro0tgmeqj3qt9j
# 4     spotify:track:4byefobulxpcqvo1kw8wdm
# 5     spotify:track:22ljag2yxlsjiwduiddcfk
# ...                                    ...
# 5034  spotify:track:2qxicqg06ot0ijkbznpgqv
# 5035  spotify:track:6o8pm5relgjd5i8gdy3irt
# 5037  spotify:track:1eothndm6kqfb2idifr30n
# 5038  spotify:track:042sl6mn83jhyleqdk7ui0
# 5039  spotify:track:3bcn2pcy0ktg1zm8tz9msb
#
#                                              track_href  \
# 1     https://api.spotify.com/v1/tracks/14qcrx6dfjvc...
# 2     https://api.spotify.com/v1/tracks/7k9z3yfnnlv5...
# 3     https://api.spotify.com/v1/tracks/3koawrm1ro0t...
# 4     https://api.spotify.com/v1/tracks/4byefobulxpc...
# 5     https://api.spotify.com/v1/tracks/22ljag2yxlsj...
# ...                                                 ...
# 5034  https://api.spotify.com/v1/tracks/2qxicqg06ot0...
# 5035  https://api.spotify.com/v1/tracks/6o8pm5relgjd...
# 5037  https://api.spotify.com/v1/tracks/1eothndm6kqf...
# 5038  https://api.spotify.com/v1/tracks/042sl6mn83jh...
# 5039  https://api.spotify.com/v1/tracks/3bcn2pcy0ktg...
#
#                                            analysis_url duration_ms  \
# 1     https://api.spotify.com/v1/audio-analysis/14qc...    0.076639
# 2     https://api.spotify.com/v1/audio-analysis/7k9z...    0.073800
# 3     https://api.spotify.com/v1/audio-analysis/3koa...    0.043263
# 4     https://api.spotify.com/v1/audio-analysis/4bye...    0.147167
# 5     https://api.spotify.com/v1/audio-analysis/22lj...    0.073178
# ...                                                 ...         ...
# 5034  https://api.spotify.com/v1/audio-analysis/2qxi...    0.115554
# 5035  https://api.spotify.com/v1/audio-analysis/6o8p...    0.115830
# 5037  https://api.spotify.com/v1/audio-analysis/1eot...    0.055822
# 5038  https://api.spotify.com/v1/audio-analysis/042s...    0.128387
# 5039  https://api.spotify.com/v1/audio-analysis/3bcn...    0.110822
#
#      time_signature
# 1               0.8
# 2               0.8
# 3               0.8
# 4               0.8
# 5               0.6
# ...             ...
# 5034            0.8
# 5035            0.6
# 5037            0.8
# 5038            0.8
# 5039            0.6
#
# [4290 rows x 22 columns]
# Dataset cleaned and saved as 'cleaned_dataset.csv'
#                                            trackname  \
# 1  "in the hall of the mountain king" from peer g...
# 2                                 #brooklynbloodpop!
# 3                                                $10
# 4                         (i just) died in your arms
# 5                                      (l)only child
#
#                   artistname  msplayed              genre  danceability  \
# 1  london symphony orchestra  0.011405  british orchestra      0.486680
# 2                       syko  0.000919         glitchcore      0.707992
# 3               good morning  0.000158   experimental pop      0.639344
# 4               cutting crew  0.034761         album rock      0.640369
# 5                salem ilese  0.014132              alt z      0.660861
#
#      energy       key  loudness  mode  speechiness  ...  liveness   valence  \
# 1  0.129189  0.636364  0.539908   1.0     0.054198  ...  0.081035  0.123732
# 2  0.814614  0.090909  0.849114   0.0     0.124336  ...  0.363220  0.516227
# 3  0.596160  0.363636  0.715586   1.0     0.033369  ...  0.100202  0.908722
# 4  0.726431  1.000000  0.680117   0.0     0.047184  ...  0.040038  0.514199
# 5  0.611191  0.727273  0.801682   0.0     0.145590  ...  0.225855  0.654158
#
#       tempo            type                      id  \
# 1  0.475203  audio_features  14qcrx6dfjvcj0h8ov8ouw
# 2  0.558909  audio_features  7k9z3yfnnlv5kwtjqygjnu
# 3  0.512155  audio_features  3koawrm1ro0tgmeqj3qt9j
# 4  0.528989  audio_features  4byefobulxpcqvo1kw8wdm
# 5  0.666713  audio_features  22ljag2yxlsjiwduiddcfk
#
#                                     uri  \
# 1  spotify:track:14qcrx6dfjvcj0h8ov8ouw
# 2  spotify:track:7k9z3yfnnlv5kwtjqygjnu
# 3  spotify:track:3koawrm1ro0tgmeqj3qt9j
# 4  spotify:track:4byefobulxpcqvo1kw8wdm
# 5  spotify:track:22ljag2yxlsjiwduiddcfk
#
#                                           track_href  \
# 1  https://api.spotify.com/v1/tracks/14qcrx6dfjvc...
# 2  https://api.spotify.com/v1/tracks/7k9z3yfnnlv5...
# 3  https://api.spotify.com/v1/tracks/3koawrm1ro0t...
# 4  https://api.spotify.com/v1/tracks/4byefobulxpc...
# 5  https://api.spotify.com/v1/tracks/22ljag2yxlsj...
#
#                                         analysis_url duration_ms  \
# 1  https://api.spotify.com/v1/audio-analysis/14qc...    0.076639
# 2  https://api.spotify.com/v1/audio-analysis/7k9z...    0.073800
# 3  https://api.spotify.com/v1/audio-analysis/3koa...    0.043263
# 4  https://api.spotify.com/v1/audio-analysis/4bye...    0.147167
# 5  https://api.spotify.com/v1/audio-analysis/22lj...    0.073178
#
#   time_signature
# 1            0.8
# 2            0.8
# 3            0.8
# 4            0.8
# 5            0.6
#
# [5 rows x 22 columns]

# %%
def merge_datasets(new_playlist_df, song_attr_df):
    """
    Clean and merge the playlist and attributes datasets on track name and artist name.
    Returns the merged DataFrame.
    """

    # Merge on track name + artist name
    merged_df = pd.merge(
        new_playlist_df,
        song_attr_df,
        on=['track_name'],
        how='inner'  # or 'left' depending on what you want to keep
    )

    return merged_df
merge_datasets(new_playlist_df, song_attr_df)
# Out:
#                               user_id    artist_name_x track_name  \
# 0    944c80d26922ae634d6ce445b1fdff7f        Passenger         27
# 1    944c80d26922ae634d6ce445b1fdff7f       Lily Allen         22
# 2    c50566d83fba17b20697039d5824db78           Hurula         22
# 3    c50566d83fba17b20697039d5824db78     Molotov Jive         29
# 4    c50566d83fba17b20697039d5824db78     Molotov Jive         29
# ..                                ...              ...        ...
# 920  edea424cdf88985d97bd74c9bc3674fd  Alison Crockett      alive
# 921  edea424cdf88985d97bd74c9bc3674fd  Alison Crockett      alive
# 922  edea424cdf88985d97bd74c9bc3674fd  Alison Crockett      alive
# 923  edea424cdf88985d97bd74c9bc3674fd  Alison Crockett      alive
# 924  8d27d5741b3210e41ab3a499c1141af9           Unseen       1984
#
#              playlistname      artist_name_y  msplayed                  genre  \
# 0                    HATK     loving caliber  0.018050              scandipop
# 1                 Starred       taylor swift  0.003757                    pop
# 2      Everything at once       taylor swift  0.003757                    pop
# 3      Everything at once        chris james  0.000873  singer-songwriter pop
# 4      Everything at once    run river north  0.000229       stomp and holler
# ..                    ...                ...       ...                    ...
# 920          Astralizzare        audrey mika  0.002483       modern indie pop
# 921          Astralizzare  empire of the sun  0.000571       australian dance
# 922          Astralizzare             khalid  0.001120                    pop
# 923          Astralizzare             willis  0.002938          alabama indie
# 924  Mis pistas de Shazam             glaive  0.002897             glitchcore
#
#      danceability    energy       key  ...  liveness   valence     tempo  \
# 0        0.627049  0.361672  0.000000  ...  0.091684  0.465517  0.592910
# 1        0.657787  0.695366  0.636364  ...  0.053668  0.651116  0.440245
# 2        0.657787  0.695366  0.636364  ...  0.053668  0.651116  0.440245
# 3        0.796107  0.597162  0.363636  ...  0.087424  0.912779  0.566707
# 4        0.449795  0.903800  0.636364  ...  0.238633  0.278905  0.664592
# ..            ...       ...       ...  ...       ...       ...       ...
# 920      0.605533  0.334616  0.818182  ...  0.077415  0.297160  0.366001
# 921      0.536885  0.885762  0.454545  ...  0.048877  0.400609  0.507858
# 922      0.395492  0.405764  1.000000  ...  0.155574  0.207911  0.332842
# 923      0.630123  0.372695  0.545455  ...  0.169418  0.487830  0.372445
# 924      0.681352  0.746473  0.818182  ...  0.131083  0.432049  0.571555
#
#                type                      id  \
# 0    audio_features  3r7w1kne3d3ke1jpnyifwm
# 1    audio_features  3yii7uwglf6k5zw3xad3mp
# 2    audio_features  3yii7uwglf6k5zw3xad3mp
# 3    audio_features  0ahovvrk5frfzvf8fp7pzp
# 4    audio_features  0y30gl6j3y3xdxk3scoctp
# ..              ...                     ...
# 920  audio_features  39lmkwlmeetbr80uy7hivu
# 921  audio_features  5wbnkcespwsvwhuzmljs3s
# 922  audio_features  12vqhhz4wvvcnedsivjleq
# 923  audio_features  7jzhp7ixsvgtm6zdwugwip
# 924  audio_features  1bqhfaew4jigpjl0o23jns
#
#                                       uri  \
# 0    spotify:track:3r7w1kne3d3ke1jpnyifwm
# 1    spotify:track:3yii7uwglf6k5zw3xad3mp
# 2    spotify:track:3yii7uwglf6k5zw3xad3mp
# 3    spotify:track:0ahovvrk5frfzvf8fp7pzp
# 4    spotify:track:0y30gl6j3y3xdxk3scoctp
# ..                                    ...
# 920  spotify:track:39lmkwlmeetbr80uy7hivu
# 921  spotify:track:5wbnkcespwsvwhuzmljs3s
# 922  spotify:track:12vqhhz4wvvcnedsivjleq
# 923  spotify:track:7jzhp7ixsvgtm6zdwugwip
# 924  spotify:track:1bqhfaew4jigpjl0o23jns
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/3r7w1kne3d3k...
# 1    https://api.spotify.com/v1/tracks/3yii7uwglf6k...
# 2    https://api.spotify.com/v1/tracks/3yii7uwglf6k...
# 3    https://api.spotify.com/v1/tracks/0ahovvrk5frf...
# 4    https://api.spotify.com/v1/tracks/0y30gl6j3y3x...
# ..                                                 ...
# 920  https://api.spotify.com/v1/tracks/39lmkwlmeetb...
# 921  https://api.spotify.com/v1/tracks/5wbnkcespwsv...
# 922  https://api.spotify.com/v1/tracks/12vqhhz4wvvc...
# 923  https://api.spotify.com/v1/tracks/7jzhp7ixsvgt...
# 924  https://api.spotify.com/v1/tracks/1bqhfaew4jig...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/3r7w...    0.109588
# 1    https://api.spotify.com/v1/audio-analysis/3yii...    0.120256
# 2    https://api.spotify.com/v1/audio-analysis/3yii...    0.120256
# 3    https://api.spotify.com/v1/audio-analysis/0aho...    0.069810
# 4    https://api.spotify.com/v1/audio-analysis/0y30...    0.107280
# ..                                                 ...         ...
# 920  https://api.spotify.com/v1/audio-analysis/39lm...    0.101893
# 921  https://api.spotify.com/v1/audio-analysis/5wbn...    0.105903
# 922  https://api.spotify.com/v1/audio-analysis/12vq...    0.091110
# 923  https://api.spotify.com/v1/audio-analysis/7jzh...    0.078985
# 924  https://api.spotify.com/v1/audio-analysis/1bqh...    0.076310
#
#     time_signature
# 0              0.8
# 1              0.8
# 2              0.8
# 3              0.8
# 4              0.8
# ..             ...
# 920            1.0
# 921            0.8
# 922            0.8
# 923            0.8
# 924            0.8
#
# [925 rows x 25 columns]

# %%
from gensim.models import Word2Vec

# Create unique song identifier
df['song_id'] = df['track_name'].str.lower() + ' - ' + df['artist_name'].str.lower()

# Group songs by playlist
playlists = df.groupby('playlistname')['song_id'].apply(list).tolist()

# Train Word2Vec model
model = Word2Vec(
    sentences=playlists,
    vector_size=100,
    window=5,
    min_count=1,
    sg=1,
    workers=4,
    epochs=20
)

# Save model
model.save("song_word2vec.model")

# Example: Find similar songs
song_query = 'blinding lights - the weeknd'
if song_query in model.wv:
    similar_songs = model.wv.most_similar(song_query, topn=10)
    for song, score in similar_songs:
        print(f"{song} (score: {score:.3f})")
else:
    print("Song not in vocabulary.")

# %%
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Example user input
user_preferences = {
    'genre': 'pop',
    'mood': 'happy',  # high valence
    'energy': 0.7,
    'danceability': 0.6,
    'favorite_song': 'blinding lights'  # example seed
}

# Map mood to valence threshold
mood_valence_map = {
    'happy': 0.6,
    'sad': 0.3,
    'energetic': 0.7,
    'calm': 0.4
}
valence_threshold = mood_valence_map.get(user_preferences['mood'], 0.5)

# Make a full song key (assuming trackname is unique enough)
merged_df['song_key'] = merged_df['track_name'].str.lower().str.strip()

# Check if the favorite song is in the model
seed_song = user_preferences['favorite_song'].lower().strip()
if seed_song not in w2v_model.wv:
    print(f"'{seed_song}' not in vocabulary. Please choose another song.")
else:
    # Get most similar songs using Word2Vec
    similar_songs = w2v_model.wv.most_similar(seed_song, topn=500)
    similar_song_names = [song for song, sim in similar_songs]

    # Filter merged_df to contain only songs in similar list
    filtered_df = merged_df[merged_df['song_key'].isin(similar_song_names)].copy()

    # Apply additional metadata filters
    filtered_df = filtered_df[
        (filtered_df['genre'].str.lower() == user_preferences['genre'].lower()) &
        (filtered_df['valence'] >= valence_threshold) &
        (filtered_df['energy'] >= user_preferences['energy']) &
        (filtered_df['danceability'] >= user_preferences['danceability'])
    ]

    # Rank songs by Word2Vec similarity score
    similarity_scores = []
    for song in filtered_df['song_key']:
        sim_score = w2v_model.wv.similarity(seed_song, song)
        similarity_scores.append(sim_score)

    filtered_df['similarity'] = similarity_scores

    # Sort by similarity
    ranked_df = filtered_df.sort_values(by='similarity', ascending=False)

    # Show top 10 recommendations
    recommendations = ranked_df[['track_name', 'artist_name', 'genre', 'valence', 'similarity']].head(10)
    print("Top Recommendations:")
    print(recommendations)
